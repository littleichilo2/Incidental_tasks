# %% [markdown]
# AWS
# 	オンプレミス
# 	初期費用
# 	設定費用
#
# 全球化，低價格
# capacity 予測不要
# 最新加速技術
# 維修維持費用不要
#
#
# 18個Region
#
# 54個AZ
# 20180213 Osaka Local Region
#
#
# Amazon EC2
# 容量可變
# 可自編譯
# 容量課金
# 20060826 提供開始 m1.small
#
# AMI中OS安裝 啟動虛擬伺服器
#
# Amazon machine image
# 1.OS
# 2.account 啟動權限
# 3.可自編譯
# aws marketplace
#
# instance type
# c5.4xlarge
# instance family 世代 size
# 挑選最適合的instance
# 選擇更強的instance更能節省計算時間，減少cost
# instance userdata
# 預先設置要安裝的APP
# 每次啟動OS就可以設置
# instance metadata
# 可以取得instance本身的IP位址等等
# 確認instance userdata
#
# 三種購入方式
# 時間課金
# 契約
# spot
#
#
# Amazon elastic Block store
#
# Amazon S3
# 200603
# https/https
# scable
# 用量無限制
# 一個檔案最大量5TB
# 檔案會在三個region製作副本
# object key表示object的識別子
# s3並沒有資料夾的概念
# security
# access control list(ACL)
# IAM policy
# data暗號化
# versioning(版本管理)
# 同名的檔案被儲存時，會自動存成不同檔案
# Amazon Glacier(低頻度使用便宜方案)
# 備份的話可以使用S3 IA
# lifecyclepolicy
# 可以自動設定檔案存放方式
# 低頻度的檔案最後可以選擇刪除
#
#
# Amazon VPC
#
#
#
#
# Scability
# 	autoscaling
# 		autoscaling  elastic load balancing
# 			啟動設定
#
# 			autoscaling group
# 				最小啟動 最大啟動 希望(server)
#
# 			動的スケーリング
# 				cloudwatch
# 					cloudwatch alarm
# 					auto healing
#
# 		ELB
# 			load balancer
# 				healthcheck
# 				internet loadbalance
# 				內部load balancer
# 				HTTPS load balancer
#
# 		Amazon Cloud Watch
# 			monitoring
# 			alarm option
# 				autoscaling
# 				email alart
# 			cpuutilization
# 			statusCheck
# 			pageViewCount
# 			CloudWatch Events
#
# 	best practice and support tool
# 		aws well architected framework
# 		Trusted advisor
# 		simple monthly calculator
#
# Security accessability
# 	IAM(Identity and access management)
# 		IAM user
# 			認証：
# 				1.username password
# 				2.Access key SecretAccesskey(お勧めしない)
#
#
# 		IAM group
# 			only IAM user can control
#
# 		IAM role
# 			可取代access key
# 		IAM policy
# 			JSON的方式記述權限
# 			deny first
#
# 	ベストプラクティス
# 		accesskey delete
# 		IAM user create
# 		IAM group
# 		最小権限
# 		IAM role
#
# データベース
# 	Amazon RDS
# 		RDBMS =リレーショナルデータベース
# 			MYSQL/PostgreSQL/MariaDB/Oracle DB
# 		RDS的導入可以專念在APP最佳化，短時間構築
# 		DB instance
# 			自動備份
# 			手動snapshot
# 		安全性
# 			VPC內啟動
# 			SSL
# 		マルチAZ配置
# 		Amazon RDS for Aurora
# 			同時執行數多與大表格
# 	Amazon DynamoDB
# 		NoSQL=No Only SQL
# 			key value store/document orient/
# 			水平スケーラビリティ
# 			key and value
